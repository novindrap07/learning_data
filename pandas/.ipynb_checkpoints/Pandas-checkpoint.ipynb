# %% [markdown]
# ## 2 Introducing the most important objects: Series and DataFrames

# %%
# The importing convetion
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2.1 The Pandas Series
# #### The series data structure in Pandas is a one-dimensional labeled array

# %% [markdown]
# ## 2.2 Creating a Pandas Series

# %%
# define the data and index as lists
temperature = [33, 19, 15, 89, 11, -5, 9]
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
# create series 
series_from_lists = pd.Series(temperature, index=days)
series_from_lists
# Out:
# Mon    33
# Tue    19
# Wed    15
# Thu    89
# Fri    11
# Sat    -5
# Sun     9
# dtype: int64

# %%
# from a dictioary
my_dict = {'Mon': 33, 'Tue': 19, 'Wed': 15, 'Thu': 89, 'Fri': 11, 'Sat': -5, 'Sun': 9}
series_from_dict = pd.Series(my_dict)
series_from_dict
# Out:
# Mon    33
# Tue    19
# Wed    15
# Thu    89
# Fri    11
# Sat    -5
# Sun     9
# dtype: int64

# %%
# from a numpy array
my_array = np.linspace(0,10,15)
series_from_ndarray = pd.Series(my_array)
series_from_ndarray
# Out:
# 0      0.000000
# 1      0.714286
# 2      1.428571
# 3      2.142857
# 4      2.857143
# 5      3.571429
# 6      4.285714
# 7      5.000000
# 8      5.714286
# 9      6.428571
# 10     7.142857
# 11     7.857143
# 12     8.571429
# 13     9.285714
# 14    10.000000
# dtype: float64

# %%
# vectorized operations also wprk in pandas series
2*series_from_lists
# Out:
# Mon     66
# Tue     38
# Wed     30
# Thu    178
# Fri     22
# Sat    -10
# Sun     18
# dtype: int64

# %% [markdown]
# ## 2.3 Pandas DataFrames
#
# #### Dataframe is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects.

# %% [markdown]
# ## 3.1 Reading the data
#
# #### Sample data : HR Employee Attrition and Performance. You can get it from here :
#
# #### https://www.ibm.com/communities/analytics/watson-analytics-blog/hr-employee-attrition/

# %%
# 1:25
file_url =  "WA_Fn-UseC_-HR-Employee-Attrition.xlsx"

# %%
data = pd.read_excel(io=file_url, sheet_name=0, index_col='EmployeeNumber')

# %% [markdown]
# ## 3.2 The anatomy of DataFrame
#
# #### A DataFrame consists on three parts :
#
# #### 1. Index
# #### 2. Columns Names (Column Index)
# #### 3. Data
#
# #### The row and column labels can be accessed respectively by accessing the index and columns attributes:

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.index
# Out:
# Int64Index([   1,    2,    4,    5,    7,    8,   10,   11,   12,   13,
#             ...
#             2054, 2055, 2056, 2057, 2060, 2061, 2062, 2064, 2065, 2068],
#            dtype='int64', name='EmployeeNumber', length=1470)

# %%
data.values
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %% [markdown]
# ## 3.3 Inspecting your data

# %%
data.head()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# 4               Research & Development                 2          2
# 5               Research & Development                 3          4
# 7               Research & Development                 2          1
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# ...

# %%
data.tail()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 2061            Research & Development                23          2
# 2062            Research & Development                 6          1
# 2064            Research & Development                 4          3
# 2065                             Sales                 2          3
# 2068            Research & Development                 8          3
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# ...

# %% [markdown]
# ## 3.4 Selection, addition, deletion
#
# #### You can treat a DataFrame like a dict of Indexed Series objects. Getting, setting, and deleting, columns work with the same syntax dictionary operations:

# %%
#Getting one column: .head() is just to print the first 5 values
data['Age']#.head()
# Out:
# EmployeeNumber
# 1       41
# 2       49
# 4       37
# 5       33
# 7       27
# 8       32
# 10      59
# 11      30
# 12      38
# 13      36
# 14      35
# 15      29
# 16      31
# 18      34
# 19      28
# 20      29
# 21      32
# 22      22
# 23      53
# 24      38
# 26      24
# 27      36
# 28      34
# 30      21
# 31      34
# 32      53
# 33      32
# 35      42
# 36      44
# 38      46
#         ..
# 2025    36
# 2026    56
# 2027    29
# 2031    42
# 2032    56
# 2034    41
# 2035    34
# 2036    36
# 2037    41
# 2038    32
# 2040    35
# 2041    38
# 2044    50
# 2045    36
# 2046    45
# 2048    40
# 2049    35
# 2051    40
# 2052    35
# 2053    29
# 2054    29
# 2055    50
# 2056    39
# 2057    31
# 2060    26
# 2061    36
# 2062    39
# 2064    27
# 2065    49
# 2068    34
# Name: Age, Length: 1470, dtype: int64

# %%
# Getting more than one column
data[['Age', 'Gender', 'YearsAtCompany']]#.head()
# Out:
#                 Age  Gender  YearsAtCompany
# EmployeeNumber
# 1                41  Female               6
# 2                49    Male              10
# 4                37    Male               0
# 5                33  Female               8
# 7                27    Male               2
# 8                32    Male               7
# 10               59  Female               1
# 11               30    Male               1
# 12               38    Male               9
# 13               36    Male               7
# 14               35    Male               5
# 15               29  Female               9
# 16               31    Male               5
# 18               34    Male               2
# 19               28    Male               4
# 20               29  Female              10
# 21               32    Male               6
# 22               22    Male               1
# 23               53  Female              25
# 24               38    Male               3
# ...

# %%
# Adding a column
data['AgeInMonths'] = 12*data['Age']
data['AgeInMonths']#.head()
# Out:
# EmployeeNumber
# 1       492
# 2       588
# 4       444
# 5       396
# 7       324
# 8       384
# 10      708
# 11      360
# 12      456
# 13      432
# 14      420
# 15      348
# 16      372
# 18      408
# 19      336
# 20      348
# 21      384
# 22      264
# 23      636
# 24      456
# 26      288
# 27      432
# 28      408
# 30      252
# 31      408
# 32      636
# 33      384
# 35      504
# 36      528
# 38      552
#        ...
# 2025    432
# 2026    672
# 2027    348
# 2031    504
# 2032    672
# 2034    492
# 2035    408
# 2036    432
# 2037    492
# 2038    384
# 2040    420
# 2041    456
# 2044    600
# 2045    432
# 2046    540
# 2048    480
# 2049    420
# 2051    480
# 2052    420
# 2053    348
# 2054    348
# 2055    600
# 2056    468
# 2057    372
# 2060    312
# 2061    432
# 2062    468
# 2064    324
# 2065    588
# 2068    408
# Name: AgeInMonths, Length: 1470, dtype: int64

# %%
# Deleting a column
del data['AgeInMonths']
# The drop method can also be used
data.drop('EmployeeCount', axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## 3.4.1 Slices

# %%
data['BusinessTravel'][10:15]
# Out:
# EmployeeNumber
# 14    Travel_Rarely
# 15    Travel_Rarely
# 16    Travel_Rarely
# 18    Travel_Rarely
# 19    Travel_Rarely
# Name: BusinessTravel, dtype: object

# %%
data[10:15]
# Out:
#                 Age Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 14               35        No  Travel_Rarely        809
# 15               29        No  Travel_Rarely        153
# 16               31        No  Travel_Rarely        670
# 18               34        No  Travel_Rarely       1346
# 19               28       Yes  Travel_Rarely        103
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 14              Research & Development                16          3
# 15              Research & Development                15          2
# 16              Research & Development                26          1
# 18              Research & Development                19          2
# 19              Research & Development                24          3
#
#                EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                  ...
# ...

# %% [markdown]
# ## 3.4.2 Selection by label

# %%
selected_EmployeeNumbers = [15, 94, 337, 1120]

# %%
data['YearsAtCompany'].loc[selected_EmployeeNumbers]
# Out:
# EmployeeNumber
# 15      9
# 94      5
# 337     2
# 1120    7
# Name: YearsAtCompany, dtype: int64

# %%
data.loc[selected_EmployeeNumbers]
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 15               29        No      Travel_Rarely        153
# 94               29        No      Travel_Rarely       1328
# 337              31        No  Travel_Frequently       1327
# 1120             29        No      Travel_Rarely       1107
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 15              Research & Development                15          2
# 94              Research & Development                 2          3
# 337             Research & Development                 3          4
# 1120            Research & Development                28          4
#
#                EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                  ...
# 15              Life Sciences                        4  Female  ...
# 94              Life Sciences                        3    Male  ...
# ...

# %%
# Getting a single value
data.loc[94, 'YearsAtCompany']
# Out:
# 5

# %% [markdown]
# #### It's also possible to selected by position using the iloc method

# %% [markdown]
# ## 3.5 Answering simple questions about a dataset
#
# #### The HR director asks you to answer a few descriptive questions about employees, you use this dataset to answer them:
#
# #### 1. How many employees are there by departement in the dataset?
# #### 2. What is the overall attrion rate?
# #### 3. What is the average hourly rate?
# #### 4. What is the average number of years at the company?
# #### 5. Who are the 5 employees with the most number of years at the company?
# #### 6. How satisfied are employees overall?

# %% [markdown]
# ## 3.5.1 How many employees are there by departement in the dataset?

# %%
data['Department']#.value_counts()
# Out:
# EmployeeNumber
# 1                        Sales
# 2       Research & Development
# 4       Research & Development
# 5       Research & Development
# 7       Research & Development
# 8       Research & Development
# 10      Research & Development
# 11      Research & Development
# 12      Research & Development
# 13      Research & Development
# 14      Research & Development
# 15      Research & Development
# 16      Research & Development
# 18      Research & Development
# 19      Research & Development
# 20      Research & Development
# 21      Research & Development
# 22      Research & Development
# 23                       Sales
# 24      Research & Development
# 26      Research & Development
# 27                       Sales
# 28      Research & Development
# 30      Research & Development
# 31      Research & Development
# 32      Research & Development
# 33      Research & Development
# 35                       Sales
# 36      Research & Development
# ...

# %% [markdown]
# ## 3.5.2 What is the overall attrion rate?

# %%
data['Attrition']#.value_counts()
# Out:
# EmployeeNumber
# 1       Yes
# 2        No
# 4       Yes
# 5        No
# 7        No
# 8        No
# 10       No
# 11       No
# 12       No
# 13       No
# 14       No
# 15       No
# 16       No
# 18       No
# 19      Yes
# 20       No
# 21       No
# 22       No
# 23       No
# 24       No
# 26       No
# 27      Yes
# 28       No
# 30       No
# 31      Yes
# 32       No
# 33      Yes
# 35       No
# 36       No
# 38       No
#        ...
# 2025     No
# 2026     No
# 2027    Yes
# 2031     No
# 2032    Yes
# 2034     No
# 2035     No
# 2036     No
# 2037     No
# 2038     No
# 2040     No
# 2041     No
# 2044    Yes
# 2045     No
# 2046     No
# 2048     No
# 2049     No
# 2051     No
# 2052     No
# 2053     No
# 2054     No
# 2055    Yes
# 2056     No
# 2057     No
# 2060     No
# 2061     No
# 2062     No
# 2064     No
# 2065     No
# 2068     No
# Name: Attrition, Length: 1470, dtype: object

# %%
data['Attrition'].value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %%
attrition_rate = data['Attrition'].value_counts(normalize=True)['Yes']
attrition_rate
# Out:
# 0.16122448979591836

# %% [markdown]
# ## 3.5.3 What is the average hourly rate?

# %%
data['HourlyRate'].mean()
# Out:
# 65.89115646258503

# %% [markdown]
# ## 3.5.4 What is the average number of years at the company?

# %%
data['YearsAtCompany'].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# ## 3.5.5 Who are the 5 employees with the most number of years at the company?

# %%
data['YearsAtCompany'].sort_values(ascending=False)#[:5]
# Out:
# EmployeeNumber
# 165     40
# 131     37
# 374     36
# 1578    36
# 776     34
# 259     33
# 329     33
# 1352    33
# 1278    33
# 1572    33
# 644     32
# 1539    32
# 1038    32
# 825     31
# 638     31
# 905     31
# 1606    30
# 549     29
# 1282    29
# 569     27
# 80      27
# 944     26
# 1602    26
# 1204    26
# 820     26
# 1288    25
# 158     25
# 520     25
# 23      25
# 244     24
#         ..
# 775      0
# 1624     0
# 4        0
# 1853     0
# 30       0
# 405      0
# 1734     0
# 1515     0
# 1306     0
# 411      0
# 1368     0
# 1943     0
# 144      0
# 1012     0
# 366      0
# 364      0
# 1203     0
# 994      0
# 1758     0
# 167      0
# 1803     0
# 1113     0
# 945      0
# 1494     0
# 1115     0
# 614      0
# 1504     0
# 618      0
# 1935     0
# 1839     0
# Name: YearsAtCompany, Length: 1470, dtype: int64

# %%
data['YearsAtCompany'].sort_values(ascending=False)[:5].index
# Out:
# Int64Index([165, 131, 374, 1578, 776], dtype='int64', name='EmployeeNumber')

# %% [markdown]
# ## 3.5.6 How satisfied are employees overall?

# %%
data['JobSatisfaction']#.head()
# Out:
# EmployeeNumber
# 1       4
# 2       2
# 4       3
# 5       3
# 7       2
# 8       4
# 10      1
# 11      3
# 12      3
# 13      3
# 14      2
# 15      3
# 16      3
# 18      4
# 19      3
# 20      1
# 21      2
# 22      4
# 23      4
# 24      4
# 26      3
# 27      1
# 28      2
# 30      4
# 31      1
# 32      3
# 33      1
# 35      2
# 36      4
# 38      1
#        ..
# 2025    2
# 2026    3
# 2027    4
# 2031    3
# 2032    3
# 2034    2
# 2035    3
# 2036    4
# 2037    2
# 2038    1
# 2040    4
# 2041    4
# 2044    3
# 2045    4
# 2046    3
# 2048    3
# 2049    3
# 2051    3
# 2052    4
# 2053    2
# 2054    1
# 2055    1
# 2056    4
# 2057    1
# 2060    3
# 2061    4
# 2062    1
# 2064    2
# 2065    2
# 2068    3
# Name: JobSatisfaction, Length: 1470, dtype: int64

# %%
data['JobSatisfaction'].head()
# Out:
# EmployeeNumber
# 1    4
# 2    2
# 4    3
# 5    3
# 7    2
# Name: JobSatisfaction, dtype: int64

# %%
JobSatisfaction_cat = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High' 
}

# %%
data['JobSatisfaction'] = data['JobSatisfaction'].map(JobSatisfaction_cat)
data['JobSatisfaction'].head()
# Out:
# EmployeeNumber
# 1    Very High
# 2       Medium
# 4         High
# 5         High
# 7       Medium
# Name: JobSatisfaction, dtype: object

# %%
data['JobSatisfaction'].value_counts()
# Out:
# Very High    459
# High         442
# Low          289
# Medium       280
# Name: JobSatisfaction, dtype: int64

# %%
100*data['JobSatisfaction'].value_counts(normalize=True)
# Out:
# Very High    31.224490
# High         30.068027
# Low          19.659864
# Medium       19.047619
# Name: JobSatisfaction, dtype: float64

# %%
data['JobSatisfaction'].value_counts().plot(kind='bar')

# %%
data['JobSatisfaction'] = data['JobSatisfaction'].astype(dtype='category', 
                                                         categories=['Low', 'Medium', 'High', 'Very High'], 
                                                         ordered=True)
data['JobSatisfaction'].head()
# Out:
# /home/novindra/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3296: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)
# EmployeeNumber
# 1    Very High
# 2       Medium
# 4         High
# 5         High
# 7       Medium
# Name: JobSatisfaction, dtype: category
# Categories (4, object): [Low < Medium < High < Very High]

# %%
data['JobSatisfaction'].value_counts(sort=False).plot(kind='bar')

# %% [markdown]
# ## 3.6.1 Give me the list of the employees with Low level of JobSatisfaction

# %%
data['JobSatisfaction'] == 'Low'
# Out:
# EmployeeNumber
# 1       False
# 2       False
# 4       False
# 5       False
# 7       False
# 8       False
# 10       True
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 18      False
# 19      False
# 20       True
# 21      False
# 22      False
# 23      False
# 24      False
# 26      False
# 27       True
# 28      False
# 30      False
# 31       True
# 32      False
# 33       True
# 35      False
# 36      False
# 38       True
#         ...
# 2025    False
# 2026    False
# 2027    False
# 2031    False
# 2032    False
# 2034    False
# 2035    False
# 2036    False
# 2037    False
# 2038     True
# 2040    False
# 2041    False
# 2044    False
# 2045    False
# 2046    False
# 2048    False
# 2049    False
# 2051    False
# 2052    False
# 2053    False
# 2054     True
# 2055     True
# 2056    False
# 2057     True
# 2060    False
# 2061    False
# 2062     True
# 2064    False
# 2065    False
# 2068    False
# ...

# %% [markdown]
# #### We can use a boolean series to index a Series or a DataFrame, this is called "Masking" or boolean indexing.

# %%
data.loc[data['JobSatisfaction'] == 'Low']#.index
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 10               59        No      Travel_Rarely       1324
# 20               29        No      Travel_Rarely       1389
# 27               36       Yes      Travel_Rarely       1218
# 31               34       Yes      Travel_Rarely        699
# 33               32       Yes  Travel_Frequently       1125
# 38               46        No      Travel_Rarely        705
# 51               36        No      Travel_Rarely        852
# 52               33        No  Travel_Frequently       1141
# 54               27        No      Travel_Rarely       1240
# 68               44        No      Travel_Rarely       1488
# 70               35        No         Non-Travel       1097
# 74               35        No  Travel_Frequently        853
# 75               35        No      Travel_Rarely       1142
# 81               59        No      Travel_Rarely       1435
# ...

# %% [markdown]
# ## 3.6.2 Give me the list of the employees with Low level of both JobSatisfaction and JobInvolment

# %%
JobInvolment_cat = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
data['JobInvolment'] = data['JobInvolvement'].map(JobInvolment_cat)

# %%
data.loc[(data['JobSatisfaction'] == 'Low') & (data['JobInvolment'] == 'Low')].index.values
# Out:
# array([  33,  235,  454,  615, 1019, 1037, 1237, 1460, 1478, 1544, 1611,
#        1622, 1905, 1956])

# %% [markdown]
# ## 3.6.3 Compare the employees with Low and Very High JobSatisfaction acroos the following variables: Agw, Departement and DistanceFromHome

# %% [markdown]
# #### Since we are only interested in the employees with "Low" and "Very High" JobSatisfaction levels, let's create a new DataFrame containing only those observations.

# %%
subset_of_interest = data.loc[(data['JobSatisfaction'] == "Low") | (data['JobSatisfaction'] == "Very High")]
subset_of_interest.shape
# Out:
# (748, 34)

# %% [markdown]
# #### Since our JobSatisfaction variable had 4 categories, this categories have stayed in the series of this

# %%
subset_of_interest['JobSatisfaction'].value_counts()
# Out:
# Very High    459
# Low          289
# High           0
# Medium         0
# Name: JobSatisfaction, dtype: int64

# %% [markdown]
# #### Let's remove those categories we won't be using:

# %%
#subset_of_interest['JobSatisfaction'].cat.remove_unused_categories(inplace=True)

# %%
subset_of_interest['JobSatisfaction'].value_counts()
# Out:
# Very High    459
# Low          289
# High           0
# Medium         0
# Name: JobSatisfaction, dtype: int64

# %% [markdown]
# #### Now we only the employees we are interested in, we can now compare accross the variables we wanted. First let's split our new DataFrame intp groups.

# %%
grouped = subset_of_interest.groupby('JobSatisfaction')

# %%
grouped.groups
# Out:
# {'Low': Int64Index([  10,   20,   27,   31,   33,   38,   51,   52,   54,   68,
#              ...
#              1975, 1980, 1998, 2021, 2023, 2038, 2054, 2055, 2057, 2062],
#             dtype='int64', name='EmployeeNumber', length=289),
#  'Medium': Int64Index([], dtype='int64', name='EmployeeNumber'),
#  'High': Int64Index([], dtype='int64', name='EmployeeNumber'),
#  'Very High': Int64Index([   1,    8,   18,   22,   23,   24,   30,   36,   39,   40,
#              ...
#              2022, 2024, 2027, 2036, 2040, 2041, 2045, 2052, 2056, 2061],
#             dtype='int64', name='EmployeeNumber', length=459)}

# %%
grouped.get_group('Low').head()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 10               59        No      Travel_Rarely       1324
# 20               29        No      Travel_Rarely       1389
# 27               36       Yes      Travel_Rarely       1218
# 31               34       Yes      Travel_Rarely        699
# 33               32       Yes  Travel_Frequently       1125
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 10              Research & Development                 3          3
# 20              Research & Development                21          4
# 27                               Sales                 9          4
# 31              Research & Development                 6          1
# 33              Research & Development                16          1
#
#                EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                  ...
# ...

# %%
grouped.get_group('Low').tail()
# Out:
#                 Age Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 2038             32        No  Travel_Rarely        529
# 2054             29        No  Travel_Rarely        468
# 2055             50       Yes  Travel_Rarely        410
# 2057             31        No     Non-Travel        325
# 2062             39        No  Travel_Rarely        613
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 2038            Research & Development                 2          3
# 2054            Research & Development                28          4
# 2055                             Sales                28          3
# 2057            Research & Development                 5          3
# 2062            Research & Development                 6          1
#
#                   EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                     ...
# ...

# %%
grouped.get_group('Very High').head()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 8                32        No  Travel_Frequently       1005
# 18               34        No      Travel_Rarely       1346
# 22               22        No         Non-Travel       1123
# 23               53        No      Travel_Rarely       1219
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 8               Research & Development                 2          2
# 18              Research & Development                19          2
# 22              Research & Development                16          2
# 23                               Sales                 2          4
#
#                EducationField  EnvironmentSatisfaction  Gender  ...  \
# EmployeeNumber                                                  ...
# ...

# %% [markdown]
# ### 3.6.3.1 Age

# %%
grouped['Age']

# %%
grouped['Age'].mean()
# Out:
# JobSatisfaction
# Low          36.916955
# Medium             NaN
# High               NaN
# Very High    36.795207
# Name: Age, dtype: float64

# %%
grouped['Age'].describe()
# Out:
#                  count       mean       std   min   25%   50%   75%   max
# JobSatisfaction
# Low              289.0  36.916955  9.245496  19.0  30.0  36.0  42.0  60.0
# Medium             0.0        NaN       NaN   NaN   NaN   NaN   NaN   NaN
# High               0.0        NaN       NaN   NaN   NaN   NaN   NaN   NaN
# Very High        459.0  36.795207  9.125609  18.0  30.0  35.0  43.0  60.0

# %%
grouped['Age'].describe().stack()
# Out:
# JobSatisfaction
# Low              count    289.000000
#                  mean      36.916955
#                  std        9.245496
#                  min       19.000000
#                  25%       30.000000
#                  50%       36.000000
#                  75%       42.000000
#                  max       60.000000
# Medium           count      0.000000
# High             count      0.000000
# Very High        count    459.000000
#                  mean      36.795207
#                  std        9.125609
#                  min       18.000000
#                  25%       30.000000
#                  50%       35.000000
#                  75%       43.000000
#                  max       60.000000
# dtype: float64

# %%
grouped['Age'].describe().unstack()
# Out:
#        JobSatisfaction
# count  Low                289.000000
#        Medium               0.000000
#        High                 0.000000
#        Very High          459.000000
# mean   Low                 36.916955
#        Medium                    NaN
#        High                      NaN
#        Very High           36.795207
# std    Low                  9.245496
#        Medium                    NaN
#        High                      NaN
#        Very High            9.125609
# min    Low                 19.000000
#        Medium                    NaN
#        High                      NaN
#        Very High           18.000000
# 25%    Low                 30.000000
#        Medium                    NaN
#        High                      NaN
#        Very High           30.000000
# 50%    Low                 36.000000
#        Medium                    NaN
#        High                      NaN
#        Very High           35.000000
# 75%    Low                 42.000000
# ...

# %% [markdown]
# ### 3.6.3.2 Department

# %%
grouped['Department'].apply
# Out:
# <bound method SeriesGroupBy.apply of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7f3a04e72b00>>

# %%
##Skip

# %% [markdown]
# ### 3.6.3.3 DistanceFromHome

# %%
grouped['DistanceFromHome'].describe().unstack()
# Out:
#        JobSatisfaction
# count  Low                289.000000
#        Medium               0.000000
#        High                 0.000000
#        Very High          459.000000
# mean   Low                  9.190311
#        Medium                    NaN
#        High                      NaN
#        Very High            9.030501
# std    Low                  8.045127
#        Medium                    NaN
#        High                      NaN
#        Very High            8.257004
# min    Low                  1.000000
#        Medium                    NaN
#        High                      NaN
#        Very High            1.000000
# 25%    Low                  2.000000
#        Medium                    NaN
#        High                      NaN
#        Very High            2.000000
# 50%    Low                  7.000000
#        Medium                    NaN
#        High                      NaN
#        Very High            7.000000
# 75%    Low                 14.000000
# ...

# %%
grouped['DistanceFromHome'].describe().stack()
# Out:
# JobSatisfaction
# Low              count    289.000000
#                  mean       9.190311
#                  std        8.045127
#                  min        1.000000
#                  25%        2.000000
#                  50%        7.000000
#                  75%       14.000000
#                  max       29.000000
# Medium           count      0.000000
# High             count      0.000000
# Very High        count    459.000000
#                  mean       9.030501
#                  std        8.257004
#                  min        1.000000
#                  25%        2.000000
#                  50%        7.000000
#                  75%       14.000000
#                  max       29.000000
# dtype: float64

# %%
grouped['DistanceFromHome'].describe()
# Out:
#                  count      mean       std  min  25%  50%   75%   max
# JobSatisfaction
# Low              289.0  9.190311  8.045127  1.0  2.0  7.0  14.0  29.0
# Medium             0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# High               0.0       NaN       NaN  NaN  NaN  NaN   NaN   NaN
# Very High        459.0  9.030501  8.257004  1.0  2.0  7.0  14.0  29.0

# %%
grouped['DistanceFromHome'].describe().unstack()['mean'].plot(kind='bar')

# %%
###Finish
